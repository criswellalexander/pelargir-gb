# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
b = np.array([0.5,0.5,0.75,1.])
theta_vecs = np.linspace(a-b,a+b,3)
theta_vecs
# Out:
# array([[0.5 , 1.5 , 2.25, 3.  ],
#        [1.  , 2.  , 3.  , 4.  ],
#        [1.5 , 2.5 , 3.75, 5.  ]])

# %%
theta_vecs.shape
# Out:
# (3, 4)

# %%
lnp0 = - (theta_vecs[:,0] - a[0])**2/(2*b[0]**2)
lnp0
# Out:
# array([-0.5, -0. , -0.5])

# %%
theta_vecs + lnp0[:,None]
# Out:
# array([[0.  , 1.  , 1.75, 2.5 ],
#        [1.  , 2.  , 3.  , 4.  ],
#        [1.  , 2.  , 3.25, 4.5 ]])

# %%
np.atleast_1d(np.array([1,2]))[0]
# Out:
# 1
